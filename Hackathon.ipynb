# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter('ignore')

# %%
df=pd.read_csv(r"C:\Users\yukti\Data science by SRK\Excel+CSV\StudentPerformanceFactors.csv")
df
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
df.columns
# Out:
# Index(['Hours_Studied', 'Attendance', 'Parental_Involvement',
#        'Access_to_Resources', 'Extracurricular_Activities', 'Sleep_Hours',
#        'Previous_Scores', 'Motivation_Level', 'Internet_Access',
#        'Tutoring_Sessions', 'Family_Income', 'Teacher_Quality', 'School_Type',
#        'Peer_Influence', 'Physical_Activity', 'Learning_Disabilities',
#        'Parental_Education_Level', 'Distance_from_Home', 'Gender',
#        'Exam_Score'],
#       dtype='object')

# %%
df.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %%
df.tail()
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 6602                         No            7               76
# 6603                         No            8               81
# 6604                        Yes            6               65
# 6605                        Yes            6               91
# 6606                        Yes            9               94
#
#      Motivation_Level Internet_Access  Tutoring_Sessions Family_Income  \
# 6602           Medium             Yes                  1          High
# ...

# %%
df.shape
# Out:
# (6607, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6607 non-null   int64
#  1   Attendance                  6607 non-null   int64
#  2   Parental_Involvement        6607 non-null   object
#  3   Access_to_Resources         6607 non-null   object
#  4   Extracurricular_Activities  6607 non-null   object
#  5   Sleep_Hours                 6607 non-null   int64
#  6   Previous_Scores             6607 non-null   int64
#  7   Motivation_Level            6607 non-null   object
#  8   Internet_Access             6607 non-null   object
#  9   Tutoring_Sessions           6607 non-null   int64
#  10  Family_Income               6607 non-null   object
#  11  Teacher_Quality             6529 non-null   object
#  12  School_Type                 6607 non-null   object
# ...

# %%
cat=df.select_dtypes(include='object').columns
num=df.select_dtypes(exclude='object').columns

# %%
cat,num
# Out:
# (Index(['Parental_Involvement', 'Access_to_Resources',
#         'Extracurricular_Activities', 'Motivation_Level', 'Internet_Access',
#         'Family_Income', 'Teacher_Quality', 'School_Type', 'Peer_Influence',
#         'Learning_Disabilities', 'Parental_Education_Level',
#         'Distance_from_Home', 'Gender'],
#        dtype='object'),
#  Index(['Hours_Studied', 'Attendance', 'Sleep_Hours', 'Previous_Scores',
#         'Tutoring_Sessions', 'Physical_Activity', 'Exam_Score'],
#        dtype='object'))

# %%
df.isnull().sum()
# Out:
# Hours_Studied                  0
# Attendance                     0
# Parental_Involvement           0
# Access_to_Resources            0
# Extracurricular_Activities     0
# Sleep_Hours                    0
# Previous_Scores                0
# Motivation_Level               0
# Internet_Access                0
# Tutoring_Sessions              0
# Family_Income                  0
# Teacher_Quality               78
# School_Type                    0
# Peer_Influence                 0
# Physical_Activity              0
# Learning_Disabilities          0
# Parental_Education_Level      90
# Distance_from_Home            67
# Gender                         0
# Exam_Score                     0
# dtype: int64

# %% [markdown]
# **Observation:**
#
# - in this DataSet 3 columns having null values.

# %%
Mode_Teacher_Quality=df['Teacher_Quality'].mode()
Mode_Teacher_Quality
# Out:
# 0    Medium
# Name: Teacher_Quality, dtype: object

# %%
df['Teacher_Quality'].fillna(Mode_Teacher_Quality[0],inplace=True)

# %%
Mode_Parental_Education=df['Parental_Education_Level'].mode()
Mode_Parental_Education
# Out:
# 0    High School
# Name: Parental_Education_Level, dtype: object

# %%
df['Parental_Education_Level'].fillna(Mode_Parental_Education[0],inplace=True)

# %%
Mode_Distance_From_Home=df['Distance_from_Home'].mode()
Mode_Distance_From_Home
# Out:
# 0    Near
# Name: Distance_from_Home, dtype: object

# %%
df['Distance_from_Home'].fillna(Mode_Distance_From_Home[0],inplace=True)

# %% [markdown]
# **Observation:**
#
# - Here we fill all null values

# %%
df
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
df.isnull().sum()
# Out:
# Hours_Studied                 0
# Attendance                    0
# Parental_Involvement          0
# Access_to_Resources           0
# Extracurricular_Activities    0
# Sleep_Hours                   0
# Previous_Scores               0
# Motivation_Level              0
# Internet_Access               0
# Tutoring_Sessions             0
# Family_Income                 0
# Teacher_Quality               0
# School_Type                   0
# Peer_Influence                0
# Physical_Activity             0
# Learning_Disabilities         0
# Parental_Education_Level      0
# Distance_from_Home            0
# Gender                        0
# Exam_Score                    0
# dtype: int64

# %% [markdown]
# **Observation:**
# - No null values are there in this data set.

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Observation:**
# - Data Set does't have any Duplicates.

# %%
j=1
plt.figure(figsize=(25,20))
for i in num[:-1]:
    plt.title(i)
    plt.subplot(3, 3, j)
    
    plt.hist(df[i])
    
    plt.xlabel("class")
    plt.ylabel('Frequency')
    j=j+1
    
plt.show()

# %% [markdown]
# **Observations:**
# - Parental Involvement: High (50.89%)
#
# - Access to Resources: High (50.23%)
#
# - Extracurricular Activities: Participation (59.60%)
#
# - Motivation Level: High (50.72%)
#
# - Internet Access: Widespread (92.45%)
#
# - Family Income: Balanced distribution (medium and high)
#
# - Teacher Quality: High (60.59%)
#
# - School Type: Predominantly private (69.59%)

# %%
j=1
plt.figure(figsize=(15,15))
for i in cat:
    plt.subplot(4, 4, j)
    plt.title(i)
    
    keys=df[i].value_counts().keys()
    values=df[i].value_counts().values
    j=j+1
    plt.pie(values,labels=keys,autopct='%0.2f%%')
    
plt.show()

# %% [markdown]
# **Observation:**
#
# - **Parental Involvement:**
#
#   - High involvement: 50.89%
#
#   - Medium involvement: 20.24%
#
#   - Low involvement: 28.88%
#
# - **Access to Resources:**
#
#   - High access: 50.23%
#
#   - Medium access: 19.87%
#
#   - Low access: 29.89%
#
# - **Extracurricular Activities:**
#
#   - Participation: 59.60%
#
#   - No participation: 40.40%
#
# - **Motivation Level:**
#
#   - High motivation: 50.72%
#
#   - Medium motivation: 29.32%
#
#   - Low motivation: 19.96%
#
# - **Internet Access:**
#
#   - Yes: 92.45%
#
#   - No: 7.55%
#
# - **Family Income:**
#
#   - High: 40.35%
#
#   - Medium: 40.44%
#
#   - Low: 19.21%
#
# - **Teacher Quality:**
#
#   - High quality: 60.59%
#
#   - Medium quality: 9.94%
#
#   - Low quality: 29.47%
#
# - **School Type:**
#
#   - Private: 69.59%
#
#   - Public: 30.41%

# %%
j=1
plt.figure(figsize=(25,20))
for i in num[:-1]:
    plt.subplot(3,3,j)
    plt.title(i)
    plt.boxplot(df[i],vert=False)
    j=j+1
plt.show()

# %% [markdown]
# **Observation:**
# - For Checking the Outliers We use here BoxPlot

# %%
from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()

for i in cat:
    df[i]=le.fit_transform(df[i])

# %%
df
# Out:
#       Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0                23          84                     1                    0
# 1                19          64                     1                    2
# 2                24          98                     2                    2
# 3                29          89                     1                    2
# 4                19          92                     2                    2
# ...             ...         ...                   ...                  ...
# 6602             25          69                     0                    2
# 6603             23          76                     0                    2
# 6604             20          90                     2                    1
# 6605             10          86                     0                    0
# 6606             15          67                     2                    1
#
#       Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %% [markdown]
# **Observation:**
# - We replace all the categorical data to numerical data.

# %%
ver=df.corr(numeric_only=True)
plt.figure(figsize=(25,20))
sns.heatmap(ver,annot=True)
plt.show()

# %% [markdown]
# **Observation:**
# - From this heatmap we can see that their is 45% variance between Hours_Studied & Exam score. that means if the number of hours studied will increse it will affect the exam score in a positive way.
# - The attendence also playing a major roll by having the variance of a 58% that means if the attendence of the students is gone a increase the exam score will also increse.

# %% [markdown]
# **Q1.Based on your analysis, suggest targeted interventions that could improve student
# performance, such as additional tutoring, better parental engagement, or changes in
# school policies.**
#
# **1. increase Study Hours**
#
# Hours Studied has the highest positive correlation (0.45) with Exam Scores, making it the most critical factor for academic success.
#
# **2. Improve Attendance**
#
# Attendance has a strong positive correlation (0.36) with Exam Scores, highlighting the importance of consistent classroom learning.
#
# **3. Enhance Access to Resources**
#
# Access to Resources shows a strong positive correlation with Hours Studied (0.61), indirectly influencing exam scores.

# %% [markdown]
# **Q2.Recommendations for Addressing Disparities in Student Performance Based on Demographic Factors**
#
# **1. Enhance Access to Resources**
#
# Access_to_Resources shows a strong positive correlation with Hours Studied (0.61), which directly impacts exam performance. Students from low-income families or underserved areas may have limited access to learning resources.
#
# **2.Improve Attendance Rates Across Demographics**
#
# Attendance has a strong positive correlation (0.36) with Exam Scores. Students from certain demographic groups (e.g., those living far from school or with unstable family situations) may face challenges in attending regularly.
#
# **3. Target Parental Engagement Initiatives**
#
# While Parental Involvement shows a mild negative correlation (-0.094) with Exam Scores, this may indicate over-involvement for struggling students or lack of balanced engagement.
